# %%
#importing the required packages
import pandas as pd

# %% [markdown]
# ### Que1
# [R] After loading the data into the pandas dataframe df, write code to identify the number of rows and columns that df has, and print them.

# %%
df = pd.read_csv('22n0451_IE507_lab09_ex1.csv')

# %%
#check the data frame by printing its first few rows 
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 0                                     2.3                   3.0
# 1                                     1.5                   2.0
# ...

# %%
#check the data frame by printing its last  few rows 
df.tail()
# Out:
#       age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 298  45.0  1.0              1.0    110.0              264.0              0.0
# 299  68.0  1.0              4.0    144.0              193.0              1.0
# 300  57.0  1.0              4.0    130.0              131.0              0.0
# 301  57.0  0.0              2.0    130.0              236.0              0.0
# 302  38.0  1.0              3.0    138.0              175.0              0.0
#
#      rest_ecg  max_heartrate  exercise_angina  \
# 298       0.0          132.0              0.0
# 299       0.0          141.0              0.0
# 300       0.0          115.0              1.0
# 301       2.0          174.0              0.0
# 302       0.0          173.0              0.0
#
#      ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 298                                     1.2                   2.0
# 299                                     3.4                   2.0
# ...

# %%
print(df.shape)
print(f'number of rows:{df.shape[0]}')
print(f'number of columns {df.shape[1]}')
# Out:
# (303, 14)
# number of rows:303
# number of columns 14

# %%
#Printing the columns in df
print(df.columns)
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'rest_bp', 'serum_cholesterol',
#        'fastblood_sugar', 'rest_ecg', 'max_heartrate', 'exercise_angina',
#        'ST_depression_exercise_relativeto_rest', 'slope_peak_STsegment',
#        'num_major_vessels_fluroscopy', 'thal', 'heart_disease_status'],
#       dtype='object')

# %%
#Let us try to check the description of the data 
data_description = open('22n0451_IE507_lab09_ex1.txt','r').read()
print (data_description)
# Out:
# Publication Request:
#    >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#    This file describes the contents of the heart-disease directory.
#
#    This directory contains 1 database concerning heart disease diagnosis.
#    All attributes are numeric-valued.  The data was collected from the
#     following location:
#
#      1. Cleveland Clinic Foundation (cleveland.data)
#
# While the database contains 76 attributes, only  14 attributes were actually used in past experiments.
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# 1. Title: Heart Disease Databases
#
# 2. Source Information:
#    (a) Creators:
#        -- 1. Hungarian Institute of Cardiology. Budapest: Andras Janosi, M.D.
#    (b) Donor: David W. Aha (aha@ics.uci.edu) (714) 856-8779
#    (c) Date: July, 1988
#
#
# 3. Relevant Information:
#      This database contains 76 attributes, but all published experiments
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    float64
#  2   chest_pain_type                         303 non-null    float64
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    float64
#  6   rest_ecg                                303 non-null    float64
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    float64
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %%
#If an explicit description about data is missing, we can try to understand the data using basic statistical information
df.describe()
# Out:
#               age         sex  chest_pain_type     rest_bp  serum_cholesterol  \
# count  303.000000  303.000000       303.000000  303.000000         303.000000
# mean    54.438944    0.679868         3.158416  131.689769         246.693069
# std      9.038662    0.467299         0.960126   17.599748          51.776918
# min     29.000000    0.000000         1.000000   94.000000         126.000000
# 25%     48.000000    0.000000         3.000000  120.000000         211.000000
# 50%     56.000000    1.000000         3.000000  130.000000         241.000000
# 75%     61.000000    1.000000         4.000000  140.000000         275.000000
# max     77.000000    1.000000         4.000000  200.000000         564.000000
#
#        fastblood_sugar    rest_ecg  max_heartrate  exercise_angina  \
# count       303.000000  303.000000     303.000000       303.000000
# mean          0.148515    0.990099     149.607261         0.326733
# ...

# %% [markdown]
# ## Que2
# [R] Why are the num major vessels fluroscopy and thal columns considered object types?Write the reason.
# ## Answer
# Num_major_vessels_flurscopy and thal columns are considered object data type since as mentioned in description of data, Num_major_vessels_flurscopy is showing the diagnosis of heart disease(angigraphic desease status) where value 0 in data shows that angiographic disease status is less than 50% diamete narrowing and value 1 is showing that  angiographic disease status is greater than 50% diamete narrowing.Hence values given in columns are denoting some string values.Similarly in "thal" column defect is shown where value "3" shows that defect is normal,value "6" shows that defect is fixed defect and value "7" shows that defect is reversable defect.So values in column "Thal" represents strings.So data type of data in these two columns are given object data type.

# %%
#we can use the following for attributes with object dtype 
df.describe(include=object)
# Out:
#        num_major_vessels_fluroscopy thal
# count                           303  303
# unique                            5    4
# top                             0.0  3.0
# freq                            176  166

# %%
#we change the sex attribute to categorical
df["sex"] = df["sex"].astype('category')

# %%
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest  slope_peak_STsegment  \
# 0                                     2.3                   3.0
# 1                                     1.5                   2.0
# ...

# %%
df.describe(include='category')
# Out:
#           sex
# count   303.0
# unique    2.0
# top       1.0
# freq    206.0

# %% [markdown]
# ### Que3:[R] Find another categorical attribute in df, change its dtype to ‘category’. Then use describe() to see statistics of that attribute.
# ### Answer:
# According to data column named "slope_peak_STsegment" can be categorical attribute in df since according to description of data values in column are representing string data(value 1:upsloping, value 2:flat, value 3: downsloping) it can be defined as follow:
#
#  slope: the slope of the peak exercise ST segment \\
#   Value 1: upsloping \\
#   Value 2: flat \\
#   Value 3: downsloping

# %%
df['slope_peak_STsegment']=df['slope_peak_STsegment'].astype('category')

# %%
df.describe(include='category')
# Out:
#           sex  slope_peak_STsegment
# count   303.0                 303.0
# unique    2.0                   3.0
# top       1.0                   1.0
# freq    206.0                 142.0

# %%
#To get other information about the data, we can use info() 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     303 non-null    float64
#  1   sex                                     303 non-null    category
#  2   chest_pain_type                         303 non-null    float64
#  3   rest_bp                                 303 non-null    float64
#  4   serum_cholesterol                       303 non-null    float64
#  5   fastblood_sugar                         303 non-null    float64
#  6   rest_ecg                                303 non-null    float64
#  7   max_heartrate                           303 non-null    float64
#  8   exercise_angina                         303 non-null    float64
#  9   ST_depression_exercise_relativeto_rest  303 non-null    float64
# ...

# %%
#We can plot histograms using various packages
#For now we shall import seaborn package
import seaborn as sns

# %%
#seaborn has its own histogram plotting utility
sns.histplot(df.age)

# %%
#To avoid the appearance of <matplotlib.axes._subplots.AxesSubplot at 0x7fe18fb1c8d0> 
# we shall end the plot command with a semicolon (;)
sns.histplot(df.age);

# %%
#We can change some options in histplot and try replotting
sns.histplot(df.age,binrange=(20,60));

# %%
#The age distribution can be plotted as a graph based on the underlying histogram 
sns.histplot(df.age,kde=True);

# %% [markdown]
# ### Ques4:[R] What is the KDE option useful for in histplot()? Explain the details.
# ### Answer:
# KDE option is useful method for visualization of distribution of observations in dataset.KDE represents the data using a continuous probability density curve in one or more dimensions.Kernel density estimation is a technique for estimation of probability density function that is a must-have enabling the user to better analyse the studied probability distribution than when using a traditional histogram.

# %%
sns.histplot(df.age,bins=20,kde=True);

# %%
sns.histplot(df.age,bins=50,kde=True);

# %% [markdown]
# ### Question5:[R] Plot seaborn based histogram with kde=True for serum cholesterol attribute. Use bin sizes from {default, 20, 50, 100, 200, 500}. Report the observations.
# ### Answer:

# %%
sns.histplot(df.serum_cholesterol,kde=True)

# %%
sns.histplot(df.serum_cholesterol,bins=20,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=50,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=100,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=200,kde=True);

# %%
sns.histplot(df.serum_cholesterol,bins=500,kde=True);

# %% [markdown]
# ### So by above plots it can be observed that as soon as value of bin size increases hight of kde decreases since as soon as bin size increases(number of bins increases) so each bin take lower value on x-axis so serum_cholesterol is divided into more parts as soon as value of bin size increases so we can visualize is more properly but KDE's hight decreases since as soon as serum_cholesterol value divided into smaller parts then values in that reason are  also lesser than last time so mean of these values of decreases so hight of KDE also increases.

# %%
import numpy as np
#Let us use bar plots now to understand about the data description
#To do this let us first introduce new column to the data frame indicating the gender of patient
df['gender'] = np.where(df['sex']==1.0,'male','female')

# %%
df.head()
#check the last column
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest slope_peak_STsegment  \
# 0                                     2.3                  3.0
# 1                                     1.5                  2.0
# ...

# %%
#We will plot bar plots using seaborn
sns.catplot(x="gender",data=df,kind='count');

# %%
sns.catplot(x="chest_pain_type",data=df,kind='count');

# %%
#Let us plot the bar plot for gender vs serum_cholesterol 
sns.barplot(x="gender",y="serum_cholesterol",data=df);
#What does the plot describe? What are the vertical black bars in each bar?

# %% [markdown]
# ### 6.[R] Change the order in the bar plots for gender vs serum cholesterol from male, female to female, male and replot.
# ### Answer:

# %%
new_order=('female','male')
sns.barplot(x="gender",y="serum_cholesterol",data=df,order=new_order );

# %%
df1=df.groupby('gender')['serum_cholesterol']
df1.describe()
# Out:
#         count        mean        std    min     25%    50%    75%    max
# gender
# female   97.0  261.752577  64.900891  141.0  215.00  254.0  302.0  564.0
# male    206.0  239.601942  42.649757  126.0  208.75  235.0  268.5  353.0

# %%
sns.barplot(x="gender",y="serum_cholesterol",data=df);

# %%
#Let us try the barplot with a different option
sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.median );

# %% [markdown]
# ### Que7[R] Explain the difference between the bar plot obtained using the median estimator for gender vs serum cholesterol and the bar plot obtained before.
# ### Answer:
# the difference between the bar plot obtained using the median estimator va serum cholesterol and the bar plot obtained before is that first time when we didn't define any specific estimator then by default it takes "np.mean" by default as estimator.In the bar plot black bars are showing corresponding estimator values.In first curve when estimator is np.mean then black bar shows the mean serum cholesterol corresponding to "male" and "female". Similarly when estimator was np.median then black bar shows the median values of cholesterol corresponding to 'male' and 'female'.

# %%
sns.barplot(x="gender",y="serum_cholesterol",data=df,estimator=np.mean );

# %%
#We can create bar plots with even more fine-grained grouping
#Let us group according to chest_pain_type
sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df);
#[R] Explain the observations from the plot.

# %%
#We can adjust the positioning of the legend. 
ax = sns.barplot(x="gender",y="serum_cholesterol",hue="chest_pain_type",data=df)
ax.legend(loc='center left', title="chest_pain_type", bbox_to_anchor=(1, 0.5));

# %% [markdown]
# ### Question8:[R] Explain the observations from the bar plot containing gender vs serum cholesterol grouped according to chest pain type.
# ### Answer:
# After grouping of data according to chest pain type it is easy to visualise the serum_cholesterol (mg/dl) quantity in each gender and in each type of chest pain. \\
# As we can see that in female gender,quantity of serum_cholesterol is increasing with respect to defined numbers.But in male gender, quantity of serum_cholesterol is varying up and down that is for 1st and 3rd type of chest pain,serum_cholesterol is almost same and for 2nd and 4th types of chest pains, serum cholesterol is almost same.

# %% [markdown]
# ### Question9.
# [R] Note that the chest pain type attribute is numerical and hence is of less value in the
# bar plot obtained for gender vs serum cholesterol grouped according to chest pain type.
# To make the plot more meaningful, insert a new column to the dataframe which contains
# the description according to the corresponding chest pain type code. Name this column
# as chest pain type description. To fill the values in this chest pain type description
# column, take the description for chest pain type from description file. Construct the bar
# plot for gender vs serum cholesterol grouped according to chest pain type description.
# Add an appropriate legend and display the legend in a position where the bar graphs are clearly
# visible.

# %%
def rplc(a):
  if a==1.0:
    return "typical angina"
  elif a==2.0:
    return "atypical angina"
  elif a==3.0:
    return "non-anginal pain"  
  else:
    return "asymptomatic"    

df['chest_pain_type_description'] = df['chest_pain_type'].apply(rplc)

# %%
df.head()
# Out:
#     age  sex  chest_pain_type  rest_bp  serum_cholesterol  fastblood_sugar  \
# 0  63.0  1.0              1.0    145.0              233.0              1.0
# 1  67.0  1.0              4.0    160.0              286.0              0.0
# 2  67.0  1.0              4.0    120.0              229.0              0.0
# 3  37.0  1.0              3.0    130.0              250.0              0.0
# 4  41.0  0.0              2.0    130.0              204.0              0.0
#
#    rest_ecg  max_heartrate  exercise_angina  \
# 0       2.0          150.0              0.0
# 1       2.0          108.0              1.0
# 2       2.0          129.0              1.0
# 3       0.0          187.0              0.0
# 4       2.0          172.0              0.0
#
#    ST_depression_exercise_relativeto_rest slope_peak_STsegment  \
# 0                                     2.3                  3.0
# 1                                     1.5                  2.0
# ...

# %%
ax1=sns.barplot(x='gender',y='serum_cholesterol',hue='chest_pain_type_description',data=df)
ax1.legend(loc='center left', title="chest_pain_type", bbox_to_anchor=(1, 0.5));

# %% [markdown]
# ### 10. [R] Explain your observations from the scatter plot obtained for age vs serum cholesterol.

# %%
#To capture whether two attributes are correlated, one way is to use scatter plot
#Let us try to see if age is related to serum_cholesterol

sns.scatterplot(x="age",y="serum_cholesterol",data=df);
#[R] Explain your observations from the scatter plot.

# %% [markdown]
# ### Answer:Above scatter plot shows value of serum_cholesterol in mg/dl with respect to each age so we can see that in age-range(30,40) serum_cholesterol is not so high and patients are few only but in age range (50-60) density of scatters is high it means that number of patients in that range is high and cholesterol serum level is also high.

# %%
#Let us plot the relation between chest_pain_type and serum_cholesterol

sns.scatterplot(x="chest_pain_type",y="serum_cholesterol",data=df);

# %%
#We can also use lineplot to plot the relationship between variables

sns.lineplot(x="age",y="serum_cholesterol",data=df);

# %%
import matplotlib.pyplot as plt

# %%
fig, axes=plt.subplots(1,2,figsize=(10,5))
sns.scatterplot(ax=axes[0],x="age",y="serum_cholesterol",data=df)
sns.lineplot(ax=axes[1],x="age",y="serum_cholesterol",data=df);

# %% [markdown]
# ### 11. [R] What do the light-colored bands and the dark central line indicate in the line plot of age vs serum cholesterol indicate?
# ### Answer:
# By above two plots we can easily see that in line plot light-colored band shows the 95% confidence interval that 95% data corresponding to that age lies in that region \\
# But dark line denotes the mean values of serum_cholesterol in given age. \\
#
# So we can say that in line plot light-colored band represents 95% confidence interval of data and dark line denotes the mean value of data with respect to parameter(x-axis).

# %%
#We can use blox plots which would provide details about summary statistics 
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",data=df);

# %% [markdown]
# ### 12. [R] What do the upper and lower boundaries of the box plot of chest pain type and serum cholesterol indicate? What does the line inside the box indicate? What are the points marked beyond the error bars? Explain.
# ### Answer:
# The upper and lower boundaries of the box plot of chest pain type and serum cholesterol indicates the 1st quartile(middle value of smallest value and median value of data) and 3rd quartile(middle value of median value and maximum value of data) respectively. \\
# The line inside the box denotes median value of serum_cholesterol in respective chest_pain_type. \\
# The points marked beyonf the error bars denotes the outliers of data with respect to chest pain type.

# %%
#We can also group the above box plots according to gender
#recall "hue" in barplot
sns.boxplot(x="chest_pain_type",y="serum_cholesterol",hue="gender",data=df);

# %% [markdown]
# ### 13. [R] Discuss the observations made from the box plot for chest pain type and serum cholesterol grouped according to gender.
# ### Answer:
# Since in above plot we can observe that in 1 type of chest pain, male patients are having more serum_cholesterol level then female patients.
# for 2 type of chest pain male patients have less serum_cholesterol level in comparison of female patients since median for male patients is less than female  patients .
#
#
# for 3 type of chest pain male patient have less serum_cholesterol level than female patients.some female patients have higher serum_chilesterol level which is behaving like an outlier than others.Some male patients are also there whose serum_cholesterol level also behaves like an outliers. \\
# for 4 type of chest pain male and female patients are almost equal in count but level of serum_cholesterol is less in male patients than female patients.

# %% [markdown]
# ### 14. [R] Use violin plot to plot the relationship between chest pain type and serum cholesterol and discuss the observations. Group the violinplots based on gender information and discuss the observations.
# ### Answer:

# %%
fig, axes=plt.subplots(1,2,figsize=(10,5))
sns.violinplot(ax=axes[0],x='chest_pain_type',y='serum_cholesterol',data=df);
sns.violinplot(ax=axes[1],x='chest_pain_type',y='serum_cholesterol',hue='gender',data=df);

# %% [markdown]
# ### Answer14:
# 1.(ungrouped) So we can easily see that maximum frequency of of data is about median point and median and quartile 1 and quartile 3 are also shown in plot. for different chest pain type 95% confidence interval is different. For 1type of chest pain type confidence interval is low but for 4 type of chest pain  confidence interval is higher than others.Median is close to each other.
# 2.(Grouped on gender) in curve we can see that in 1 type of chest pain,scatterness of serum_cholesterol level is more in male patients in comparison of female patients.In 2 type of chest pain,scatterness is same but frequency of male patients is  higher than female patients.In 3 type of chest pain confidence level is approximately same but frequence for male patients are more than female patients but maximum value of serum_cholesterol of female patients is higher than male patients. In 4 type of chest pain type there are small differences between 95% confidence level of serum_cholesterol level for male and female patients.and also between maximum and minimum values of male and female patients.

# %%
sns.jointplot(x="age", y="max_heartrate", data=df, kind="reg");

# %% [markdown]
# ### 15. [R] Describe the observations obtained from the jointplot between age and max heartrate.
# ### Answer:
# As we can see in the graph,regression line is showing that as soon as age increases value of max_heart rate decreases.

# %%
sns.pairplot(df, x_vars=["max_heartrate", "rest_bp"], y_vars=["age"],hue="gender", height=5, aspect=.8, kind="reg");

# %% [markdown]
# ### 16. [R] Explain the observations obtained from the pairplot where max heartrate and rest bp are used as x-axis variables and age is used as y-axis variable, with gender as hue.
# ### Answer:
# As we can see in above plots that regression line in both plots is with different monotonnicity.In first curve regression line between max_heartrate and age, decreases as age decreases it means that as age decreases max_heartrate also decreases in data that shows that in high aged patients max_heartrate is low but in low aged patients max_heartrate is high.For male patients slope of regression line lower than slope of regression line for female patients so in male patients decreasness in heartrate with respect to age is lower than female patients.
#
# In second plot we can see that regression line between age and rest_bp is increasing with age.That means as soon as age increases rest_bp also increases.In this situation slope of regression line is approximately same so changes in rest_bp with respect to age in male and female patients is linearly same.

# %% [markdown]
# ### Q17. [R] Prepare a pairplot with ST depression exercise relativeto rest and serum cholesterol along x axis and age along y axis with kind=‘reg’, with gender as hue. Explain the observations obtained from this pairplot.
# ### Answer:

# %%
sns.pairplot(df,x_vars=['ST_depression_exercise_relativeto_rest','serum_cholesterol'],y_vars=['age'],hue='gender',height=5,kind='reg');

# %% [markdown]
# In 1st plot we can see that regression line for both male and female increases as age increases so in data as soon as age increases value of ST_depression_exercise_relativeto_rest also increase but slope of regression line for male patiens is more than slope of regression line for female patients that means for male patients value of ST_depression_exercise_relativeto_rest increases faster with respect to age in comparison of female patients.
#
#
# Same observation is obtained in 2nd plot,regression line for both male and female increases as age increases so in data as soon as age increases value of serum_cholesterol also increase but slope of regression line for female patiens is more than slope of regression line for male patients that means for female patients value of serum_cholesterol increases faster with respect to age in comparison of male patients.

# %% [markdown]
# ### Q18. [R] Explain the observations from the pairplot with age, rest bp, serum cholesterol, max heartrate and ST depression exercise relativeto rest along both the axes, with kind=‘reg’ and gender as hue.

# %%
sns.pairplot(df, 
             x_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             y_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             hue="gender", height=2.5,kind='reg');

# %% [markdown]
# ### Answer:
# if regression line for both male and female increases as data in x-axis increases so in data as soon as data in x-axis increases value of data in y-axis also increase and if regression line for both male and female decreases as data in x-axis increases so in data as soon as data in x-axis decreases value of data in y-axis also decrease.
#
# if slope of regression line for female patiens is more than slope of regression line for male patients that means for female patients value of data in y-axis changes faster with respect to x-axis in comparison of male patients.But if slope of regression line for female patiens is low than slope of regression line for male patients that means for female patients value of data in y-axis changes faster with respect to x-axis in comparison of male patients.

# %% [markdown]
# ### Q19. [R] Change the previous pairplot so that the off-diagonal plots are regression plots. Explain the observations from this new pairplot.
# ### Answer:

# %%
sns.pairplot(df, 
             x_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             y_vars = ["age", "rest_bp", "serum_cholesterol", "max_heartrate", "ST_depression_exercise_relativeto_rest" ], 
             hue="gender", height=2.5,kind='reg');

# %% [markdown]
# ### Answer:
# if regression line for both male and female increases as data in x-axis increases so in data as soon as data in x-axis increases value of data in y-axis also increase and if regression line for both male and female decreases as data in x-axis increases so in data as soon as data in x-axis decreases value of data in y-axis also decrease.
#
# if slope of regression line for female patiens is more than slope of regression line for male patients that means for female patients value of data in y-axis changes faster with respect to x-axis in comparison of male patients.But if slope of regression line for female patiens is low than slope of regression line for male patients that means for female patients value of data in y-axis changes faster with respect to x-axis in comparison of male patients.
